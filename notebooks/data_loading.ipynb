# %%
# data_loading.ipynb

#  Importer les librairies nécessaires
import pandas as pd

# Charger le fichier CSV
data = pd.read_csv("../sonar.all-data.csv", header=None)

# Afficher les premières lignes pour vérifier le chargement
print("Aperçu des données :")
print(data.head())

#  Vérifier la forme du dataset
print("\nNombre de lignes et de colonnes :")
print(data.shape)  # Devrait afficher (208, 61)

# Vérifier le type des colonnes
print("\nTypes des colonnes :")
print(data.dtypes)

#  Vérifier les valeurs manquantes
print("\nValeurs manquantes par colonne :")
print(data.isnull().sum())

# Compter le nombre de R et M dans la colonne cible
print("\nRépartition des classes :")
print(data[60].value_counts())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 4
#       1 # data_loading.ipynb
#       2
#       3 #  Importer les librairies nécessaires
# ----> 4 import pandas as pd
#       6 # Charger le fichier CSV
#       7 data = pd.read_csv("../sonar.all-data.csv", header=None)
#
# ModuleNotFoundError: No module named 'pandas'
